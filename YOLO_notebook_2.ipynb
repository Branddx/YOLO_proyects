# %% [markdown]
# <a href="https://colab.research.google.com/github/Branddx/YOLO_proyects/blob/main/YOLO_notebook_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install necesary python Packages**

# %%
# !pip install --upgrade ultralytics

# %%
import ultralytics
ultralytics.checks()

# %%
# !pip install roboflow

# %%
#Dataset for training and valid our model (Credits to Muhammad Moin for the image repository )
from roboflow import Roboflow
rf = Roboflow(api_key="4hIhYKGrnWHaWXRqZsZg")
project = rf.workspace("objet-detect-yolov5").project("eep_detection-u9bbd")
dataset = project.version(1).download("yolov5")

# %%
# Modificar las rutas del archivo data.yaml#
# !yolo task=detect mode=train model=yolov8m.pt data='#Ruta del archivo data.yaml#' epochs=100 imgsz=640

# %%
# !pip install gdown

# %%
# Modelo entrenado previamente para realizar pruebas
# !gdown "https://drive.google.com/uc?id=1EORSWbsQirEfFtX99gREJmOBYPZ68-Dt"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1EORSWbsQirEfFtX99gREJmOBYPZ68-Dt
# From (redirected): https://drive.google.com/uc?id=1EORSWbsQirEfFtX99gREJmOBYPZ68-Dt&confirm=t&uuid=9c4b8259-e32f-4907-80d7-3de4c85fad7d
# To: /content/PPE.pt
# 100% 52.0M/52.0M [00:00<00:00, 58.0MB/s]
